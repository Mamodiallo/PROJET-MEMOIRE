# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
basebrut_Path = Path(r"C:\Projet memoire\data\1_raw\AMV_GDT_P3M.csv")

# %%
df = pd.read_csv(basebrut_Path, sep=";", encoding="latin-1")

# %%
print(df)
# Out:
#       IDdefiche                         Courriel  Téléphone  Composeurmanuel  \
# 0         39928               aarbona0@orange.fr        NaN                0
# 1         39929  abdurahmanidzemilja74@gmail.com        NaN                0
# 2         39930             aby.sarah@hotmail.fr        NaN                0
# 3         39931       adrien.lanerouge@gmail.com        NaN                0
# 4         39932            adrien-bar@hotmail.fr        NaN                0
# ...         ...                              ...        ...              ...
# 2427      42355      cyrille.tavernier@orange.fr        NaN                0
# 2428      42356       lucchesilauriane@gmail.com        NaN                0
# 2429      42357         dominiquedebant@yahoo.fr        NaN                0
# 2430      42358             chocozoe01@gmail.com        NaN                0
# 2431      42359        francois.vezie@wanadoo.fr        NaN                0
#
# ...

# %%
display(df)
# Out:
#       IDdefiche                         Courriel  Téléphone  Composeurmanuel  \
# 0         39928               aarbona0@orange.fr        NaN                0
# 1         39929  abdurahmanidzemilja74@gmail.com        NaN                0
# 2         39930             aby.sarah@hotmail.fr        NaN                0
# 3         39931       adrien.lanerouge@gmail.com        NaN                0
# 4         39932            adrien-bar@hotmail.fr        NaN                0
# ...         ...                              ...        ...              ...
# 2427      42355      cyrille.tavernier@orange.fr        NaN                0
# 2428      42356       lucchesilauriane@gmail.com        NaN                0
# 2429      42357         dominiquedebant@yahoo.fr        NaN                0
# 2430      42358             chocozoe01@gmail.com        NaN                0
# 2431      42359        francois.vezie@wanadoo.fr        NaN                0
#
# ...
